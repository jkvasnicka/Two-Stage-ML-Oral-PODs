# %% [markdown]
# March 19, 2024 <br>
#
# # Analysis for Manuscript: *Two-Stage Machine Learning-Based Approach to Predict Points of Departure for Human Non-cancer and Developmental/Reproductive Effects*
#
# Jacob Kvasnicka1, Nicolò Aurisano2, Kerstin von Borries2, En-Hsuan Lu1, Peter Fantke2, Olivier Jolliet2, Fred A. Wright3, Weihsueh A. Chiu*1
#
# 1Department of Veterinary Physiology and Pharmacology, Interdisciplinary Faculty of Toxicology, Texas A&M University, College Station, Texas, United States
# 2Quantitative Sustainability Assessment, Department of Environmental and Resource Engineering, Technical University of Denmark, Lyngby, Denmark
# 3Departments of Statistics and Biological Sciences and Bioinformatics Research Center, North Carolina State University, Raleigh, North Carolina, United States
#
# **Corresponding Author:** Weihsueh A. Chiu, wchiu@tamu.edu <br>
# **Notebook Author:** Jacob Kvasnicka <br>

# %% [markdown]
# ## Setup

# %%
import pandas as pd
# Display maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

from raw_processing import other_sources
from config_management import UnifiedConfiguration
from data_management import DataManager
from metrics_management import MetricsManager
from results_management import ResultsManager
from results_analysis import ResultsAnalyzer
from plotting.moe import MOE_CATEGORIES

# %%
config = UnifiedConfiguration()
data_manager = DataManager(config.data, config.path)
metrics_manager = MetricsManager(config.category_to_dict('metric'))
results_manager = ResultsManager(
    results_file_type=config.data.file_type
)
results_analyzer = ResultsAnalyzer(
    results_manager, 
    data_manager,
    config.plot
)

# Get the modeling instructions for the final models
# These are used to read the corresponding results
instruction_for_model = {
    'general' : {
      'target_effect' : 'general',
      'features_source' : 'opera',
      'ld50_type' : 'predicted',
      'data_condition' : 'missing',
      'select_features' : 'true',
      'estimators' : 'RandomForestRegressor'
    },
    'repro_dev' : {
      'target_effect' : 'repro_dev',
      'features_source' : 'opera',
      'ld50_type' : 'predicted',
      'data_condition' : 'missing',
      'select_features' : 'true',
      'estimators' : 'RandomForestRegressor'  
    }
}

def get_model_key(effect):
    '''
    Helper function to get the model key for the specified effect
    category. 
    
    The model key is a unique identifier for a given model. 
    
    Parameters
    ----------
    effect : str
     Name of effect category: 'general' or 'repro_dev'.
     
    Returns
    -------
    tuple of str
        The corresponding model key.
    '''
    return tuple(instruction_for_model[effect].values())

# Define the percentiles for statistical summary
percentiles = [0.05, 0.5, 0.95]

# %% [markdown]
# ## Dataset Characterization
#
# Compute the sample sizes at each stage of data filtering. These results are summarized in manuscript **Fig. 1**.

# %%
# Get the raw surrogate PODs from Aurisano et al. (2023)
raw_surrogate_pods = other_sources.toxicity_data_and_study_counts_from_excel(
    config.path.raw_surrogate_pods_file, 
    config.raw_data.tox_metric, 
    'dtxsid', 
    config.raw_data.surrogate_tox_data_kwargs
)

for effect in list(raw_surrogate_pods.columns.unique(level=0)):
    N = len(raw_surrogate_pods[effect].dropna())
    print(f'{N} chemicals for {effect}')
# Out:
# 5209 chemicals for non-reproductive/developmental effects
# 4938 chemicals for reproductive/developmental effects

# %%
# These are the PODs with > 3 in vivo studies in ToxValDB
surrogate_pods = pd.read_csv(
    config.path.surrogate_pods_file, 
    index_col=0
)

for effect, y in list(surrogate_pods.items()):
    N = len(y.dropna())
    print(f'{N} chemicals for {effect}')
# Out:
# 2404 chemicals for general
# 2999 chemicals for repro_dev

# %%
# These are the PODs that passed the QSAR standardization workflow
# These chemicals were used for the POD modeling
for effect in surrogate_pods:    
    _, y = results_analyzer.load_features_and_target(
        **instruction_for_model[effect]
    )
    N = len(y)
    print(f'{N} chemicals for {effect}')
# Out:
# 1791 chemicals for general
# 2228 chemicals for repro_dev

# %%
application_chemicals = data_manager.load_application_chemicals()

print(f'{len(application_chemicals)} application chemicals')
# Out:
# 32524 application chemicals

# %% [markdown]
# ## Performance Evaluation
#
# Generate statistical summaries of model performance scores across replicate models. These results are summarized under the manuscript section, *Performance Evaluation and Benchmarking**.

# %%
results_analyzer.describe(
    get_model_key('general'), 
    'performances',
    percentiles=percentiles
).round(2)
# Out:
# metric  root_mean_squared_error  median_absolute_error  r2_score     gsd  \
# count                    150.00                 150.00    150.00  150.00
# mean                       0.69                   0.40      0.48    4.96
# std                        0.04                   0.02      0.04    0.43
# min                        0.61                   0.35      0.36    4.11
# 5%                         0.64                   0.37      0.41    4.37
# 50%                        0.69                   0.40      0.48    4.91
# 95%                        0.76                   0.44      0.53    5.70
# max                        0.80                   0.47      0.57    6.29
#
# metric  gsd_squared
# count        150.00
# mean          23.22
# std            4.02
# min           15.98
# 5%            18.01
# 50%           22.63
# 95%           30.29
# max           36.73

# %%
results_analyzer.describe(
    get_model_key('repro_dev'), 
    'performances',
    percentiles=percentiles
).round(2)
# Out:
# metric  root_mean_squared_error  median_absolute_error  r2_score     gsd  \
# count                    150.00                 150.00    150.00  150.00
# mean                       0.60                   0.31      0.49    4.05
# std                        0.06                   0.02      0.06    0.62
# min                        0.52                   0.26      0.35    3.29
# 5%                         0.54                   0.28      0.38    3.46
# 50%                        0.58                   0.31      0.49    3.81
# 95%                        0.72                   0.34      0.56    5.26
# max                        0.80                   0.37      0.58    6.36
#
# metric  gsd_squared
# count        150.00
# mean          15.81
# std            5.08
# min           10.29
# 5%            11.39
# 50%           13.76
# 95%           25.89
# max           37.56

# %% [markdown]
# ## Feature Importance

# %%
important_features = {}  # initialize

for effect in instruction_for_model:
    important_features[effect] = set(
        results_analyzer.get_important_features(
            get_model_key(effect)
        )
    )

# %%
# These features are common to both effect categories
important_features['general'].intersection(important_features['repro_dev'])
# Out:
# {'CATMoS_LD50_pred',
#  'CombDipolPolariz',
#  'ReadyBiodeg_pred_discrete',
#  'WS_pred'}

# %%
# These features are specific to general effects
important_features['general'].difference(important_features['repro_dev'])
# Out:
# {'MP_pred',
#  'P_pred',
#  'TopoPolSurfAir',
#  'VP_pred',
#  'nbN_discrete',
#  'ndHBdDon_discrete'}

# %%
# These features are specific to repro_dev effects
important_features['repro_dev'].difference(important_features['general'])
# Out:
# {'BCF_pred', 'FUB_pred', 'KM_pred', 'KOA_pred', 'Koc_pred', 'Sp3Sp2HybRatio'}

# %% [markdown]
# ## Sensitivity Analysis
#
# These results were used to create **Table 1.** *Comparison of performance metrics for QSAR models predicting points of departure*.

# %%
keys_without_selection = results_manager.read_model_keys(
    inclusion_string='false'
    )

results_analyzer.summarize_model_performances(
    model_keys=keys_without_selection
)
# Out:
#                                                                          0.025  \
# effect                     model_name                        metric
# General Noncancer          RandomForestRegressor (1,791)     RMSE     0.617446
#                                                              MedAE    0.345249
#                                                              $R^2$    0.427616
#                            GradientBoostingRegressor (1,791) RMSE     0.630407
#                                                              MedAE    0.367059
#                                                              $R^2$    0.402489
#                            Ridge (1,791)                     RMSE     0.668410
#                                                              MedAE    0.389967
#                                                              $R^2$    0.344460
#                            LinearRegression (1,791)          RMSE     0.668690
#                                                              MedAE    0.389858
#                                                              $R^2$    0.343969
#                            XGBRegressor (1,791)              RMSE     0.646318
#                                                              MedAE    0.366062
#                                                              $R^2$    0.325178
#                            SVR (1,791)                       RMSE     0.883227
#                                                              MedAE    0.564089
#                                                              $R^2$   -0.035467
#                            MLPRegressor (1,791)              RMSE     1.498215
#                                                              MedAE    0.569779
#                                                              $R^2$  -44.569156
#                            OPERA w/ Exp. LD50s (1,791)       RMSE     0.621115
#                                                              MedAE    0.358134
#                                                              $R^2$    0.405863
#                            CompTox Features (1,791)          RMSE     0.681206
#                                                              MedAE    0.386630
#                                                              $R^2$    0.301154
#                            RDKit Features (1,789)            RMSE     0.647720
#                                                              MedAE    0.352939
#                                                              $R^2$    0.367660
#                            No Imputation (184)               RMSE     0.441455
#                                                              MedAE    0.272213
#                                                              $R^2$   -0.031052
# Reproductive/Developmental RandomForestRegressor (2,228)     RMSE     0.519718
#                                                              MedAE    0.280855
#                                                              $R^2$    0.379977
#                            GradientBoostingRegressor (2,228) RMSE     0.538304
#                                                              MedAE    0.291164
#                                                              $R^2$    0.364841
#                            Ridge (2,228)                     RMSE     0.572986
#                                                              MedAE    0.333423
#                                                              $R^2$    0.306969
#                            LinearRegression (2,228)          RMSE     0.573032
#                                                              MedAE    0.333364
#                                                              $R^2$    0.306895
#                            XGBRegressor (2,228)              RMSE     0.558227
#                                                              MedAE    0.291223
#                                                              $R^2$    0.326422
#                            SVR (2,228)                       RMSE     0.761708
#                                                              MedAE    0.496162
#                                                              $R^2$   -0.066436
#                            MLPRegressor (2,228)              RMSE     1.101813
#                                                              MedAE    0.469202
#                                                              $R^2$  -14.418397
#                            OPERA w/ Exp. LD50s (2,228)       RMSE     0.521120
#                                                              MedAE    0.284476
#                                                              $R^2$    0.402013
#                            CompTox Features (2,228)          RMSE     0.593283
#                                                              MedAE    0.336138
#                                                              $R^2$    0.246156
#                            RDKit Features (2,224)            RMSE     0.538936
#                                                              MedAE    0.290147
#                                                              $R^2$    0.363714
#                            No Imputation (227)               RMSE     0.339944
#                                                              MedAE    0.180939
#                                                              $R^2$    0.184882
#
#                                                                          0.050  \
# effect                     model_name                        metric
# General Noncancer          RandomForestRegressor (1,791)     RMSE     0.624314
#                                                              MedAE    0.352830
#                                                              $R^2$    0.440533
#                            GradientBoostingRegressor (1,791) RMSE     0.637902
#                                                              MedAE    0.369946
#                                                              $R^2$    0.419196
#                            Ridge (1,791)                     RMSE     0.676196
#                                                              MedAE    0.402786
#                                                              $R^2$    0.356560
#                            LinearRegression (1,791)          RMSE     0.676477
#                                                              MedAE    0.403675
#                                                              $R^2$    0.356115
#                            XGBRegressor (1,791)              RMSE     0.662663
#                                                              MedAE    0.375125
#                                                              $R^2$    0.361439
#                            SVR (1,791)                       RMSE     0.892940
#                                                              MedAE    0.572148
#                                                              $R^2$   -0.030416
#                            MLPRegressor (1,791)              RMSE     1.564860
#                                                              MedAE    0.579930
#                                                              $R^2$  -36.716728
#                            OPERA w/ Exp. LD50s (1,791)       RMSE     0.631197
#                                                              MedAE    0.365507
#                                                              $R^2$    0.424309
#                            CompTox Features (1,791)          RMSE     0.688732
#                                                              MedAE    0.391126
#                                                              $R^2$    0.313089
#                            RDKit Features (1,789)            RMSE     0.653331
#                                                              MedAE    0.357828
#                                                              $R^2$    0.382910
#                            No Imputation (184)               RMSE     0.460090
#                                                              MedAE    0.280516
#                                                              $R^2$    0.020654
# Reproductive/Developmental RandomForestRegressor (2,228)     RMSE     0.527578
#                                                              MedAE    0.285660
#                                                              $R^2$    0.395624
#                            GradientBoostingRegressor (2,228) RMSE     0.543536
#                                                              MedAE    0.298303
#                                                              $R^2$    0.370971
#                            Ridge (2,228)                     RMSE     0.578070
#                                                              MedAE    0.337156
#                                                              $R^2$    0.323133
#                            LinearRegression (2,228)          RMSE     0.578220
#                                                              MedAE    0.337078
#                                                              $R^2$    0.323085
#                            XGBRegressor (2,228)              RMSE     0.564999
#                                                              MedAE    0.295173
#                                                              $R^2$    0.337097
#                            SVR (2,228)                       RMSE     0.771626
#                                                              MedAE    0.506262
#                                                              $R^2$   -0.063048
#                            MLPRegressor (2,228)              RMSE     1.178214
#                                                              MedAE    0.483124
#                                                              $R^2$  -10.680504
#                            OPERA w/ Exp. LD50s (2,228)       RMSE     0.525362
#                                                              MedAE    0.288617
#                                                              $R^2$    0.416674
#                            CompTox Features (2,228)          RMSE     0.602639
#                                                              MedAE    0.343525
#                                                              $R^2$    0.256322
#                            RDKit Features (2,224)            RMSE     0.551492
#                                                              MedAE    0.292596
#                                                              $R^2$    0.374364
#                            No Imputation (227)               RMSE     0.352791
#                                                              MedAE    0.201942
#                                                              $R^2$    0.214574
#
#                                                                         0.500  \
# effect                     model_name                        metric
# General Noncancer          RandomForestRegressor (1,791)     RMSE    0.676581
#                                                              MedAE   0.391404
#                                                              $R^2$   0.498994
#                            GradientBoostingRegressor (1,791) RMSE    0.691876
#                                                              MedAE   0.413094
#                                                              $R^2$   0.479792
#                            Ridge (1,791)                     RMSE    0.727408
#                                                              MedAE   0.437977
#                                                              $R^2$   0.420064
#                            LinearRegression (1,791)          RMSE    0.727488
#                                                              MedAE   0.438831
#                                                              $R^2$   0.420183
#                            XGBRegressor (1,791)              RMSE    0.721117
#                                                              MedAE   0.417346
#                                                              $R^2$   0.432067
#                            SVR (1,791)                       RMSE    0.962342
#                                                              MedAE   0.636841
#                                                              $R^2$  -0.007608
#                            MLPRegressor (1,791)              RMSE    2.754675
#                                                              MedAE   0.670087
#                                                              $R^2$  -7.499059
#                            OPERA w/ Exp. LD50s (1,791)       RMSE    0.686658
#                                                              MedAE   0.396599
#                                                              $R^2$   0.484621
#                            CompTox Features (1,791)          RMSE    0.750044
#                                                              MedAE   0.437734
#                                                              $R^2$   0.388067
#                            RDKit Features (1,789)            RMSE    0.711411
#                                                              MedAE   0.397300
#                                                              $R^2$   0.446279
#                            No Imputation (184)               RMSE    0.582909
#                                                              MedAE   0.371241
#                                                              $R^2$   0.222627
# Reproductive/Developmental RandomForestRegressor (2,228)     RMSE    0.572442
#                                                              MedAE   0.309858
#                                                              $R^2$   0.512129
#                            GradientBoostingRegressor (2,228) RMSE    0.588581
#                                                              MedAE   0.322405
#                                                              $R^2$   0.485997
#                            Ridge (2,228)                     RMSE    0.627259
#                                                              MedAE   0.366127
#                                                              $R^2$   0.418810
#                            LinearRegression (2,228)          RMSE    0.627347
#                                                              MedAE   0.366309
#                                                              $R^2$   0.418611
#                            XGBRegressor (2,228)              RMSE    0.616635
#                                                              MedAE   0.326650
#                                                              $R^2$   0.430282
#                            SVR (2,228)                       RMSE    0.845487
#                                                              MedAE   0.539802
#                                                              $R^2$  -0.031383
#                            MLPRegressor (2,228)              RMSE    1.754812
#                                                              MedAE   0.563136
#                                                              $R^2$  -3.433315
#                            OPERA w/ Exp. LD50s (2,228)       RMSE    0.571647
#                                                              MedAE   0.315783
#                                                              $R^2$   0.517256
#                            CompTox Features (2,228)          RMSE    0.665975
#                                                              MedAE   0.375329
#                                                              $R^2$   0.342129
#                            RDKit Features (2,224)            RMSE    0.616142
#                                                              MedAE   0.318438
#                                                              $R^2$   0.447400
#                            No Imputation (227)               RMSE    0.453375
#                                                              MedAE   0.276368
#                                                              $R^2$   0.397379
#
#                                                                         0.950  \
# effect                     model_name                        metric
# General Noncancer          RandomForestRegressor (1,791)     RMSE    0.744249
#                                                              MedAE   0.425172
#                                                              $R^2$   0.556304
#                            GradientBoostingRegressor (1,791) RMSE    0.747987
#                                                              MedAE   0.457292
#                                                              $R^2$   0.547200
#                            Ridge (1,791)                     RMSE    0.793780
#                                                              MedAE   0.478054
#                                                              $R^2$   0.478874
#                            LinearRegression (1,791)          RMSE    0.793761
#                                                              MedAE   0.480313
#                                                              $R^2$   0.478445
#                            XGBRegressor (1,791)              RMSE    0.779653
#                                                              MedAE   0.457650
#                                                              $R^2$   0.510988
#                            SVR (1,791)                       RMSE    1.041027
#                                                              MedAE   0.693553
#                                                              $R^2$   0.009734
#                            MLPRegressor (1,791)              RMSE    5.528793
#                                                              MedAE   0.835717
#                                                              $R^2$  -1.717271
#                            OPERA w/ Exp. LD50s (1,791)       RMSE    0.748439
#                                                              MedAE   0.428229
#                                                              $R^2$   0.549387
#                            CompTox Features (1,791)          RMSE    0.822482
#                                                              MedAE   0.492093
#                                                              $R^2$   0.456128
#                            RDKit Features (1,789)            RMSE    0.779051
#                                                              MedAE   0.436839
#                                                              $R^2$   0.505871
#                            No Imputation (184)               RMSE    1.173164
#                                                              MedAE   0.492175
#                                                              $R^2$   0.437873
# Reproductive/Developmental RandomForestRegressor (2,228)     RMSE    0.715178
#                                                              MedAE   0.345147
#                                                              $R^2$   0.581448
#                            GradientBoostingRegressor (2,228) RMSE    0.726193
#                                                              MedAE   0.351729
#                                                              $R^2$   0.550266
#                            Ridge (2,228)                     RMSE    0.764445
#                                                              MedAE   0.396478
#                                                              $R^2$   0.479567
#                            LinearRegression (2,228)          RMSE    0.764408
#                                                              MedAE   0.396565
#                                                              $R^2$   0.479479
#                            XGBRegressor (2,228)              RMSE    0.738311
#                                                              MedAE   0.358760
#                                                              $R^2$   0.516298
#                            SVR (2,228)                       RMSE    0.955294
#                                                              MedAE   0.576212
#                                                              $R^2$  -0.005180
#                            MLPRegressor (2,228)              RMSE    2.708388
#                                                              MedAE   0.682380
#                                                              $R^2$  -0.918133
#                            OPERA w/ Exp. LD50s (2,228)       RMSE    0.706742
#                                                              MedAE   0.342135
#                                                              $R^2$   0.580049
#                            CompTox Features (2,228)          RMSE    0.807954
#                                                              MedAE   0.409047
#                                                              $R^2$   0.440853
#                            RDKit Features (2,224)            RMSE    0.734968
#                                                              MedAE   0.346989
#                                                              $R^2$   0.524548
#                            No Imputation (227)               RMSE    0.545985
#                                                              MedAE   0.348385
#                                                              $R^2$   0.532200
#
#                                                                         0.975
# effect                     model_name                        metric
# General Noncancer          RandomForestRegressor (1,791)     RMSE    0.751592
#                                                              MedAE   0.434853
#                                                              $R^2$   0.562544
#                            GradientBoostingRegressor (1,791) RMSE    0.754663
#                                                              MedAE   0.472989
#                                                              $R^2$   0.551262
#                            Ridge (1,791)                     RMSE    0.802844
#                                                              MedAE   0.488216
#                                                              $R^2$   0.487173
#                            LinearRegression (1,791)          RMSE    0.802979
#                                                              MedAE   0.488279
#                                                              $R^2$   0.487056
#                            XGBRegressor (1,791)              RMSE    0.781978
#                                                              MedAE   0.473034
#                                                              $R^2$   0.525301
#                            SVR (1,791)                       RMSE    1.053198
#                                                              MedAE   0.701292
#                                                              $R^2$   0.011269
#                            MLPRegressor (1,791)              RMSE    6.615371
#                                                              MedAE   0.875051
#                                                              $R^2$  -1.450026
#                            OPERA w/ Exp. LD50s (1,791)       RMSE    0.757995
#                                                              MedAE   0.434010
#                                                              $R^2$   0.555553
#                            CompTox Features (1,791)          RMSE    0.832090
#                                                              MedAE   0.505383
#                                                              $R^2$   0.469271
#                            RDKit Features (1,789)            RMSE    0.807992
#                                                              MedAE   0.444011
#                                                              $R^2$   0.514373
#                            No Imputation (184)               RMSE    1.185255
#                                                              MedAE   0.497277
#                                                              $R^2$   0.464533
# Reproductive/Developmental RandomForestRegressor (2,228)     RMSE    0.735566
#                                                              MedAE   0.351714
#                                                              $R^2$   0.591477
#                            GradientBoostingRegressor (2,228) RMSE    0.744591
#                                                              MedAE   0.360556
#                                                              $R^2$   0.561571
#                            Ridge (2,228)                     RMSE    0.782187
#                                                              MedAE   0.405149
#                                                              $R^2$   0.484390
#                            LinearRegression (2,228)          RMSE    0.782277
#                                                              MedAE   0.405217
#                                                              $R^2$   0.484271
#                            XGBRegressor (2,228)              RMSE    0.753013
#                                                              MedAE   0.364181
#                                                              $R^2$   0.520941
#                            SVR (2,228)                       RMSE    0.981304
#                                                              MedAE   0.587630
#                                                              $R^2$  -0.001102
#                            MLPRegressor (2,228)              RMSE    3.219298
#                                                              MedAE   0.694879
#                                                              $R^2$  -0.780975
#                            OPERA w/ Exp. LD50s (2,228)       RMSE    0.724168
#                                                              MedAE   0.346198
#                                                              $R^2$   0.596412
#                            CompTox Features (2,228)          RMSE    0.818262
#                                                              MedAE   0.416311
#                                                              $R^2$   0.453333
#                            RDKit Features (2,224)            RMSE    0.762764
#                                                              MedAE   0.353965
#                                                              $R^2$   0.532307
#                            No Imputation (227)               RMSE    0.557178
#                                                              MedAE   0.357820
#                                                              $R^2$   0.570453

# %%
keys_with_selection = results_manager.read_model_keys(
    inclusion_string='true'
    )

results_analyzer.summarize_model_performances(
    model_keys=keys_with_selection
)
# Out:
#                                                                             0.025  \
# effect                     model_name                            metric
# General Noncancer          RandomForestRegressor (final) (1,791) RMSE    0.631001
#                                                                  MedAE   0.359110
#                                                                  $R^2$   0.402050
#                                                                  RMSE    0.631001
#                                                                  MedAE   0.359110
#                                                                  $R^2$   0.402050
# Reproductive/Developmental RandomForestRegressor (final) (2,228) RMSE    0.523493
#                                                                  MedAE   0.275471
#                                                                  $R^2$   0.363602
#                                                                  RMSE    0.523493
#                                                                  MedAE   0.275471
#                                                                  $R^2$   0.363602
#
#                                                                             0.050  \
# effect                     model_name                            metric
# General Noncancer          RandomForestRegressor (final) (1,791) RMSE    0.640619
#                                                                  MedAE   0.366414
#                                                                  $R^2$   0.408917
#                                                                  RMSE    0.640619
#                                                                  MedAE   0.366414
#                                                                  $R^2$   0.408917
# Reproductive/Developmental RandomForestRegressor (final) (2,228) RMSE    0.539058
#                                                                  MedAE   0.284368
#                                                                  $R^2$   0.381948
#                                                                  RMSE    0.539058
#                                                                  MedAE   0.284368
#                                                                  $R^2$   0.381948
#
#                                                                             0.500  \
# effect                     model_name                            metric
# General Noncancer          RandomForestRegressor (final) (1,791) RMSE    0.691144
#                                                                  MedAE   0.402057
#                                                                  $R^2$   0.479789
#                                                                  RMSE    0.691144
#                                                                  MedAE   0.402057
#                                                                  $R^2$   0.479789
# Reproductive/Developmental RandomForestRegressor (final) (2,228) RMSE    0.580969
#                                                                  MedAE   0.312614
#                                                                  $R^2$   0.494801
#                                                                  RMSE    0.580969
#                                                                  MedAE   0.312614
#                                                                  $R^2$   0.494801
#
#                                                                             0.950  \
# effect                     model_name                            metric
# General Noncancer          RandomForestRegressor (final) (1,791) RMSE    0.755731
#                                                                  MedAE   0.437987
#                                                                  $R^2$   0.532331
#                                                                  RMSE    0.755731
#                                                                  MedAE   0.437987
#                                                                  $R^2$   0.532331
# Reproductive/Developmental RandomForestRegressor (final) (2,228) RMSE    0.720956
#                                                                  MedAE   0.342014
#                                                                  $R^2$   0.562628
#                                                                  RMSE    0.720956
#                                                                  MedAE   0.342014
#                                                                  $R^2$   0.562628
#
#                                                                             0.975
# effect                     model_name                            metric
# General Noncancer          RandomForestRegressor (final) (1,791) RMSE    0.763624
#                                                                  MedAE   0.444490
#                                                                  $R^2$   0.544039
#                                                                  RMSE    0.763624
#                                                                  MedAE   0.444490
#                                                                  $R^2$   0.544039
# Reproductive/Developmental RandomForestRegressor (final) (2,228) RMSE    0.741357
#                                                                  MedAE   0.349175
#                                                                  $R^2$   0.577606
#                                                                  RMSE    0.741357
#                                                                  MedAE   0.349175
#                                                                  $R^2$   0.577606

# %% [markdown]
# ## Model Application

# %% [markdown]
# ### Median points of departure (POD) with prediction intervals
# These results correspond to the top panel of **Fig. 4.**

# %%
# Get the results for all application chemicals
pod_data = {
    effect : results_analyzer.pod_and_prediction_interval(
        get_model_key(effect),
        inverse_transform=True, 
        normalize=True
    )
    for effect in instruction_for_model
}

# Get the median value and prediction interval
for effect, df in pod_data.items():
    median = df['pod'].quantile()
    # Find the closest index to the computed median value
    abs_diff = (df['pod'] - median).abs()
    idx = abs_diff.idxmin()
    median_data = df.loc[idx]
    print(f"{effect}: {median} ({median_data['lb']}, {median_data['ub']})")
# Out:
# general: 11.218834721209232 (0.818494954674385, 153.77278965864915)
# repro_dev: 31.08881947251823 (3.442790465052367, 280.7366822905897)

# %% [markdown]
# ### Chemicals of concern based on margin of exposure (MOE)
# These results correspond to the bottom panel of **Fig. 4**.

# %%
# Get the upper bounds of the MOE concern categories
thres_for_concern = {
    k.lower().replace(' ', '_') : bounds[-1] 
    for k, bounds in MOE_CATEGORIES.items()
}

for effect in instruction_for_model:
    print(f'For {effect} effects:')

    results_for_percentile = results_analyzer.moe_and_prediction_intervals(get_model_key(effect))

    # Get the upper bound of exposure uncertainty
    ub_exposure_results = results_for_percentile['95th percentile (mg/kg/day)']
    # Get MOEs for the lower bound of the POD prediction interval
    moes = ub_exposure_results['lb']

    for concern, concern_threshold in thres_for_concern.items():
        where_potential_concern = moes <= concern_threshold
        concern_count = ub_exposure_results.loc[where_potential_concern]['cum_count'][-1]
        print(f'\t{concern_count} chemicals {concern}')
# Out:
# For general effects:
# 	33277 chemicals low_concern
# 	2337 chemicals moderate_concern
# 	497 chemicals high_concern
# For repro_dev effects:
# 	32858 chemicals low_concern
# 	1458 chemicals moderate_concern
# 	189 chemicals high_concern

# %%
# Get the exposure estimates from the SEEM3 model
exposure_df = data_manager.load_exposure_data().loc[application_chemicals]

exposure_difference = (
    exposure_df['95th percentile (mg/kg/day)'] 
    - exposure_df['5th percentile (mg/kg/day)']
)

typical_uncertainty = exposure_difference.median()

print(f'Typical exposure uncertainty: {round(typical_uncertainty)} log10-units')
# Out:
# Typical exposure uncertainty: 4 log10-units
